# %%
import os
import requests
import pandas as pd
from tqdm import tqdm
from glob import glob
from datetime import datetime
from zeep import Client, helpers

# %% [markdown]
# ### Loading in the parameters

# %%
API = pd.read_csv("api.csv")['api'].values[0]
PRODUCTION_URL = "https://openweb.nlb.gov.sg/OWS/CatalogueService.svc?singleWsdl"
client = Client(wsdl=PRODUCTION_URL)

# %% [markdown]
# ### Looking at my books

# %%
book_list = glob("/Users/cliff/main/sides/nlb/book_price/*.csv")

# %%
df = pd.DataFrame()
for book in book_list:
    df = df.append(pd.read_csv(book))

# %%
df[df.scraped_title == "Functional Training and Beyond: Building the Ultimate Superfunctional Body and Mind (Building Muscle and Performance, Weight Training, Men's Health)"]
# Out:
#                          given_title  \
# 0  The Emperors Handbook Meditations
#
#                                        scraped_title  price
# 0  Functional Training and Beyond: Building the U...  27.32

# %%
df = df[df.scraped_title != 'The Cute Book of Kawaii Coloring: Learn Japanese Words by Coloring Cute Things']
df = df[df.scraped_title != 'High-Performance Without Pain: A Companion Workbook for High-Achievers and Those Aspiring To Be']
df = df[df.scraped_title != "Functional Training and Beyond: Building the Ultimate Superfunctional Body and Mind (Building Muscle and Performance, Weight Training, Men's Health)"]

df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (234, 3)

# %%
df.head()
# Out:
#                                          given_title  \
# 0                     Seven steps to train your mind
# 1                            The Obstacle Is The Way
# 2                            Growth Hacker Marketing
# 3  Trust Me, I’m Lying: Confession of a Media Man...
# 4                     Making Habits, Breaking Habits
#
#                                        scraped_title  price
# 0                     Seven Steps to Train Your Mind  56.74
# 1  The Obstacle Is the Way: The Timeless Art of T...  23.54
# 2  Growth Hacker Marketing: A Primer on the Futur...  19.48
# 3  Trust Me, I'm Lying: Confessions of a Media Ma...  22.89
# 4  Making Habits, Breaking Habits: Why We Do Thin...  27.18

# %% [markdown]
# #### Search Feature
# - Quick search function for getting specific book details

# %%
def search_bk_by_title(title: str):
    search_input = {
        "APIKey": API,
        "SearchItems": {
            "SearchItem": [
                { "SearchField": "Title", "SearchTerms": title }, 
                { "SearchField": "MediaCode", "SearchTerms": 'BK' },
                { "SearchField": "Language", "SearchTerms": 'English' }
            ]
        },
        "Modifiers": {
            "SortSchema": None,
            "StartRecordPosition": 1,
            "MaximumRecords": 10,
            "SetId": None
        }
    }

    return search_input

def get_book_details_by_title(title: str) -> pd.DataFrame:
    try:
        book_detail_output = helpers.serialize_object(client.service.Search(**search_bk_by_title(title)))
        tmp_table = pd.DataFrame(book_detail_output.get('Titles').get('Title'))
    
    except:
        tmp_table = pd.DataFrame([[None] * 7],
            columns=['BID', 'ISBN', 'TitleName', 'Author', 'PublishYear', 'MediaCode', 'MediaDesc'])
    
    tmp_table['search_title'] = title
    return tmp_table

# %%
main = pd.DataFrame()

# %%
# Tested this
get_book_details_by_title("Predictive irrational")
# Out:
#     BID  ISBN TitleName Author PublishYear MediaCode MediaDesc  \
# 0  None  None      None   None        None      None      None
#
#             search_title
# 0  Predictive irrational

# %%
df[df['given_title'].str.contains('Predict')]
# Out:
#                                            given_title  \
# 26                               Predictive irrational
# 205  The Physics of Wall Street: A Brief History of...
#
#                                          scraped_title  price
# 26   Predictably Irrational, Revised and Expanded E...  24.18
# 205  The Physics of Wall Street: A Brief History of...  56.06

# %%
for given_title in tqdm(df['given_title'].tolist()):
    main = main.append(get_book_details_by_title(given_title))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 234/234 [02:59<00:00,  1.30it/s]

# %%
for scraped_title in tqdm(df['scraped_title'].tolist()):
    main = main.append(get_book_details_by_title(scraped_title))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 234/234 [02:04<00:00,  1.88it/s]

# %%
main.shape
# Out:
# (1051, 8)

# %%
main[main.search_title.str.contains('Predict')]
# Out:
#          BID                                        ISBN  \
# 0       None                                        None
# 0   14688206              0547317271 ()|9780547317274 ()
# 0       None                                        None
# 0  202137421  9780143125082 ((pbk.))|0143125087 ((pbk.))
# 1  203468951               9781101595954 (electronic bk)
# 0       None                                        None
#
#                                            TitleName                   Author  \
# 0                                               None                     None
# 0  The physics of Wall Street : a brief history o...  Weatherall, James Owen.
# 0                                               None                     None
# 0  The signal and the noise : why so many predict...            Silver, Nate,
# 1  The signal and the noise : why so many predict...            Silver, Nate,
# 0                                               None                     None
#
#   PublishYear MediaCode MediaDesc  \
# 0        None      None      None
# 0        2013        BK     Books
# 0        None      None      None
# 0        2015        BK     Books
# 1        2012        BK     Books
# 0        None      None      None
#
#                                         search_title
# 0                              Predictive irrational
# 0  The Physics of Wall Street: A Brief History of...
# 0  Predictably Irrational, Revised and Expanded E...
# 0  The Signal and the Noise: Why So Many Predicti...
# 1  The Signal and the Noise: Why So Many Predicti...
# 0  The Physics of Wall Street: A Brief History of...

# %%
sub_main = main.drop_duplicates()
sub_main['search_title'] = [i.strip() for i in sub_main.search_title]
sub_main = sub_main[~sub_main.ISBN.fillna('x').str.contains('electronic')]
sub_main.sort_values(['TitleName', 'PublishYear'], inplace=True)
sub_main.drop_duplicates('TitleName', inplace=True)
sub_main.drop_duplicates(['Author', 'search_title'], inplace=True)
sub_main = sub_main[(sub_main.ISBN.notnull()) & (sub_main.TitleName.notnull())]
sub_main = sub_main.append(main[main.TitleName.isnull()])
sub_main = sub_main.drop_duplicates()

sub_main.sort_values(['search_title', 'TitleName'], inplace=True)
sub_main.reset_index(drop=True, inplace=True)
print(sub_main.shape)
sub_main.head(10)
# Out:
# (371, 8)
#          BID                                               ISBN  \
# 0   12580833                             0672327279 (paperback)
# 1   14227569  9780307476463 (paperback)|0307593312 (hardcove...
# 2  202848452  9780997722901 ((paperback) :)|0997722908 ((pap...
# 3  200372552   9780141047973 (paperback)|0141047976 (paperback)
# 4       None                                               None
# 5  202701875  9783791381695 ((paperback))|3791381695 ((paper...
# 6  205500298   9781492062417 (paperback)|1492062413 (paperback)
# 7       None                                               None
# 8       None                                               None
# 9       None                                               None
#
#                                            TitleName             Author  \
# 0                    1337 h4x0r h4ndb00k / Tapeworm.          Tapeworm,
# 1  1Q84 / Haruki Murakami ; translated from the J...  Murakami, Haruki,
# 2  The global novel : writing the world in the 21...      Kirsch, Adam,
# 3  23 things they don't tell you about capitalism...    Chang, Ha-Joon,
# 4                                               None               None
# 5  50 artists you should know / Thomas Köster ; w...    Köster, Thomas,
# 6  97 things every data engineer should know : co...               None
# 7                                               None               None
# 8                                               None               None
# 9                                               None               None
#
#   PublishYear MediaCode MediaDesc  \
# 0        2005        BK     Books
# 1        2011        BK     Books
# 2        2016        BK     Books
# 3        2011        BK     Books
# 4        None      None      None
# 5        2016        BK     Books
# 6        2021        BK     Books
# 7        None      None      None
# 8        None      None      None
# 9        None      None      None
#
#                                         search_title
# 0                                1337 h4x0r H4ndb00k
# 1                                               1Q84
# 2                                               1Q84
# 3     23 things they don't tell you about capitalism
# 4                          50 Artist You Should Know
# 5                        50 Artists: You Should Know
# 6          97 Things Every Data Engineer Should Know
# 7  A Data-Driven Company: 21 Lessons for large or...
# 8  A Data-Driven Company: 21 lessons for large or...
# 9  A Guide To A Good Life: The Ancient Art of Sto...

# %%
search_checks = sub_main.search_title.value_counts().reset_index()
search_checks.columns = ['search_title', 'cnts']
print(search_checks[search_checks.cnts > 1].shape)
search_checks[search_checks.cnts > 1]
# Out:
# (37, 2)
#                                          search_title  cnts
# 0                                       Tipping Point     8
# 1                                            Outliers     8
# 2                                        Essentialism     7
# 3                                  The End of Poverty     7
# 4                               Breaking and Entering     6
# 5                                Measure What Matters     6
# 6                           Barking Up The Wrong Tree     5
# 7                               The Paradox of Choice     5
# 8                                         Sensemaking     4
# 9                               Crucial Conversations     4
# 10                           The Art of Communicating     4
# 11                           Man’s Search for Meaning     3
# 12  Big Data: A Revolution that will transform how...     3
# 13                                  Men Without Women     3
# 14                                       Smart Change     3
# 15                                 The Power of Habit     3
# 16                              The Art of Connection     3
# 17                                    Quiet Influence     3
# 18                                   The Last Lecture     3
# 19                                  The Rules of Work     2
# 20                                     Design to Grow     2
# 21                                          Deep Work     2
# 22                         How to visit an Art Museum     2
# 23                        The Upside of Irrationality     2
# 24                       The Art of Creative Thinking     2
# 25                            The Obstacle Is The Way     2
# 26  Forecast: What Physics, Meteorology, and the N...     2
# 27                                  How To Be A Stoic     2
# 28                                 Shipping Greatness     2
# 29                                   The Culture Code     2
# 30                          The Little Book of Ikigai     2
# 31                                  Dance Dance Dance     2
# 32  Big Data: Understanding How Data Powers Big Bu...     2
# 33                              Why Information Grows     2
# 34  Nudge: Improving Decisions about Health, Wealt...     2
# 35                                               1Q84     2
# 36  Quiet: The Power of Introverts in a World That...     2

# %%
sub_main[sub_main.search_title.str.contains('The End of Poverty')]
# Out:
#            BID                                               ISBN  \
# 270   13603920   1586488244 (hardcover)|9781586488246 (hardcover)
# 271   13079284                                   9787208071339 ()
# 272  203943243  3030147630 (hardcover)|9783030147631 (hardcove...
# 273  200156330                     9780385525817 ()|0385525818 ()
# 274  200561886  9780199937875 (hardback acidfree paper)|019993...
# 275  202806971  9780316471893 ((hardcover))|0316471895 ((hardc...
# 276  202250421  9781612051406 (hc alkaline paper)|1612051405 (...
#
#                                              TitleName            Author  \
# 270  Building social business : the new kind of cap...  Yunus, Muhammad,
# 271  Pin qiong de zhong jie : wo men shi dai de jin...   Sachs, Jeffrey.
# 272  The end of poverty : inequality and growth in ...    Edward, Peter,
# 273  The idealist : Jeffrey Sachs and the quest to ...       Munk, Nina,
# 274  The locust effect : why the end of poverty req...  Haugen, Gary A.,
# 275  Utopia for realists : how we can build the ide...  Bregman, Rutger,
# 276  Watching human rights : the 101 best films / b...     Gibney, Mark.
#
#     PublishYear MediaCode MediaDesc        search_title
# 270        2010        BK     Books  The End of Poverty
# 271        2007        BK     Books  The End of Poverty
# 272        2019        BK     Books  The End of Poverty
# 273        2013        BK     Books  The End of Poverty
# 274        2014        BK     Books  The End of Poverty
# 275        2017        BK     Books  The End of Poverty
# 276        2013        BK     Books  The End of Poverty

# %%
get_book_details_by_title('The End of Poverty')
# Out:
#          BID                                               ISBN  \
# 0   13603920   1586488244 (hardcover)|9781586488246 (hardcover)
# 1  203297824                      9781101643280 (electronic bk)
# 2   12525586                             0141018666 (paperback)
# 3  203943243  3030147630 (hardcover)|9783030147631 (hardcove...
# 4  203246958                                               None
# 5  200156330                     9780385525817 ()|0385525818 ()
# 6  200561886  9780199937875 (hardback acidfree paper)|019993...
# 7   13079284                                   9787208071339 ()
# 8  202806971  9780316471893 ((hardcover))|0316471895 ((hardc...
# 9  202250421  9781612051406 (hc alkaline paper)|1612051405 (...
#
#                                            TitleName             Author  \
# 0  Building social business : the new kind of cap...   Yunus, Muhammad,
# 1  The end of poverty [electronic resource] : Eco...  Sachs, Jeffrey D.
# 2  The end of poverty : how we can make it happen...    Sachs, Jeffrey.
# 3  The end of poverty : inequality and growth in ...     Edward, Peter,
# 4  The end of poverty (summary) [electronic resou...  Sachs, Jeffrey D.
# 5  The idealist : Jeffrey Sachs and the quest to ...        Munk, Nina,
# 6  The locust effect : why the end of poverty req...   Haugen, Gary A.,
# 7  Pin qiong de zhong jie : wo men shi dai de jin...    Sachs, Jeffrey.
# 8  Utopia for realists : how we can build the ide...   Bregman, Rutger,
# 9  Watching human rights : the 101 best films / b...      Gibney, Mark.
#
#   PublishYear MediaCode MediaDesc        search_title
# 0        2010        BK     Books  The End of Poverty
# 1        2006        BK     Books  The End of Poverty
# 2        2005        BK     Books  The End of Poverty
# 3        2019        BK     Books  The End of Poverty
# 4        2017        BK     Books  The End of Poverty
# 5        2013        BK     Books  The End of Poverty
# 6        2014        BK     Books  The End of Poverty
# 7        2007        BK     Books  The End of Poverty
# 8        2017        BK     Books  The End of Poverty
# 9        2013        BK     Books  The End of Poverty

# %%
sub_main[sub_main.search_title.str.contains('A Data-Driven')]
# Out:
#     BID  ISBN TitleName Author PublishYear MediaCode MediaDesc  \
# 7  None  None      None   None        None      None      None
# 8  None  None      None   None        None      None      None
#
#                                         search_title
# 7  A Data-Driven Company: 21 Lessons for large or...
# 8  A Data-Driven Company: 21 lessons for large or...

# %% [markdown]
# ### Some data cleaning

# %%
df['given_title'] = [i.replace(
    "Dark Pools: The rise of A.I. trading machines and the looming threat to Wall Street.", "Dark Pools") for i in df.given_title]

df['given_title'] = [i.replace("Predictive irrational", "Predictably irrational") for i in df.given_title]

df[df.given_title.str.contains("Predictably")]

# %%
get_book_details("Title", "0007256531")

# %%
get_book_details("Title", "Predictably irrational The Hidden Forces That Shape Our Decisions")

# %%
df[df.titlename.isnull()]

# %%
df[df.titlename.notnull()].head(30)

# %%
df['isbn'] = [get_book_isbn('Title', i) for i in tqdm(df['scraped_title'])]

# %%
get_book_isbn('Title', "Web Scraping with Python collecting")

# %%
df[df.isbn.isnull()]

# %% [markdown]
# #### Available Titles by Library

# %%
get_avail = {
    "APIKey": API,
    "BID": 204485571,
    "Modifiers" : {
        "SortSchema": None,
        "StartRecordPosition": 1,
        "MaximumRecords": 100,
        "SetId": None
    },
}

# %%
avail_info = client.service.GetAvailabilityInfo(**get_avail)

# %%
df = pd.DataFrame()
for i in pd.DataFrame(helpers.serialize_object(avail_info).get("Items").values()).T[0]:
    df = df.append(pd.DataFrame.from_dict(i, orient='index').T)
df['bid'] = 204485571
df.head()

# %% [markdown]
# #### Get Title Details

# %%
title_inputs = {
    "APIKey": API,
    # "BID": 204485571,
    "ISBN": 9780007256532
}

# %%
title_details = client.service.GetTitleDetails(**title_inputs)
title_details

# %% [markdown]
# #### Read Recommendations - Doesn't seem to work

# %%
# get_recom = {
#     "APIKey": API,
#     "BID": 204485571,
#     "Modifiers" : {
#         "SortSchema": None,
#         "StartRecordPosition": 1,
#         "MaximumRecords": 100,
#         "SetId": None
#     },
# }

# PRODUCTION_URL = "http://openweb.nlb.gov.sg/ows/ReadAlikeService.svc"
# client = Client(wsdl=PRODUCTION_URL)
# vars(client.wsdl)

# get_recommendations = client.readalikeservice.GetRecommendationsForTitles(**get_recom)
# get_recommendations
